# %%
import numpy as np
import matplotlib.pyplot as plt
from fdtd_mur import FDTD_MUR

# %%
fdtd = FDTD_MUR(Lx = 5, Ly = 5, timesteps = 501, ppw = 25, cfl = 0.7, n = 1.5, k = 0.0)


# print(fdtd.obspos_y, fdtd.obspos_x)

fdtd.createStaggeredGrid()
fdtd.setBoundaryConditionMur()
# fdtd.setBoundaryConditionPeriodic()
# fdtd.setBoundaryConditionReflective()
# fdtd.setObstacle()


fdtd.runSimulation(50)


fdtd.printTime()
# Out:
# cfl-condition:  0.6999999999754765
# ['time', 3.3021160713338726e-17]
# ['timestep ', 0]
# ['timestep ', 50]
# ['timestep ', 100]
# ['timestep ', 150]
# ['timestep ', 200]
# ['timestep ', 250]
# ['timestep ', 300]
# ['timestep ', 350]
# ['timestep ', 400]
# ['timestep ', 450]
# ['timestep ', 500]
# time for simulation 6.382776

# %%
fdtd = FDTD_MUR(Lx = 10, Ly = 5, timesteps = 501, ppw = 25, cfl = 0.7, n = 1.5, k = 0.15)
#fdtd.setBoundaryConditionPeriodic()
fdtd.createStaggeredGrid()
fdtd.setBoundaryConditionReflective()
fdtd.setBoundaryConditionMur()
# fdtd.setBoundaryConditionPeriodic()
#fdtd.setBoundaryConditionReflective()
fdtd.setObstacle()


fdtd.runSimulation(50)


fdtd.printTime()
# Out:
# cfl-condition:  0.6999999999754765
# ['time', 3.3021160713338726e-17]
# ['timestep ', 0]
# ['timestep ', 50]
# ['timestep ', 100]
# ['timestep ', 150]
# ['timestep ', 200]
# ['timestep ', 250]
# ['timestep ', 300]
# ['timestep ', 350]
# ['timestep ', 400]
# ['timestep ', 450]
# ['timestep ', 500]
# time for simulation 7.768086

# %%
fdtd = FDTD_MUR(Lx = 10, Ly = 5, timesteps = 501, ppw = 25, cfl = 0.7, n = 1.5, k = 0.0)
#fdtd.setBoundaryConditionPeriodic()
fdtd.createStaggeredGrid()
fdtd.setBoundaryConditionReflective()
fdtd.setBoundaryConditionMur()
#fdtd.setBoundaryConditionPeriodic()
#fdtd.setBoundaryConditionReflective()
fdtd.setObstacle()


fdtd.runSimulation(50)


fdtd.printTime()
# Out:
# cfl-condition:  0.6999999999754765
# ['time', 3.3021160713338726e-17]
# ['timestep ', 0]
# ['timestep ', 50]
# ['timestep ', 100]
# ['timestep ', 150]
# ['timestep ', 200]
# ['timestep ', 250]
# ['timestep ', 300]
# ['timestep ', 350]
# ['timestep ', 400]
# ['timestep ', 450]
# ['timestep ', 500]
# time for simulation 4.002649
